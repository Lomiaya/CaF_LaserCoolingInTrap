# %%
using QuantumStates
# Out:
# ERROR: LoadError: too many parameters for type AbstractTriangular
# Stacktrace:
#  [1] top-level scope
#    @ C:\Users\lomia\.julia\packages\ArrayLayouts\kR7AR\src\memorylayout.jl:719
#  [2] include(mod::Module, _path::String)
#    @ Base .\Base.jl:557
#  [3] include(x::String)
#    @ ArrayLayouts C:\Users\lomia\.julia\packages\ArrayLayouts\kR7AR\src\ArrayLayouts.jl:1
#  [4] top-level scope
#    @ C:\Users\lomia\.julia\packages\ArrayLayouts\kR7AR\src\ArrayLayouts.jl:103
#  [5] include
#    @ .\Base.jl:557 [inlined]
#  [6] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
#    @ Base .\loading.jl:2881
#  [7] top-level scope
#    @ stdin:6
# in expression starting at C:\Users\lomia\.julia\packages\ArrayLayouts\kR7AR\src\memorylayout.jl:719
# ...
